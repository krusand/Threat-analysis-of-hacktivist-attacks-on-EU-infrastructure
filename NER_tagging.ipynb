# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
hacktivist_messages = pd.read_csv("data/hacktivist_messages.csv", sep=";")
hacktivist_messages = hacktivist_messages.dropna()

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
import math

# load tagger
tagger = SequenceTagger.load("flair/ner-english-fast")

tagged_texts = []
for row in tqdm(hacktivist_messages.iterrows(), total=hacktivist_messages.shape[0]):
    text = Sentence(row[1]["Text"])
    tagger.predict(text)
    tagged_texts.append(text)

hacktivist_messages["NER"] = tagged_texts
# Out:
# 2024-09-04 14:46:14,081 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# 100%|██████████| 2995/2995 [18:06<00:00,  2.76it/s]

# %%
tagger_ontonotes = SequenceTagger.load("ner-ontonotes-fast")

tagged_texts_ontonotes = []
for row in tqdm(hacktivist_messages.iterrows(), total=hacktivist_messages.shape[0]):
    text = Sentence(row[1]["Text"])
    tagger_ontonotes.predict(text)
    tagged_texts_ontonotes.append(text)

hacktivist_messages["NER_onto"] = tagged_texts_ontonotes
# Out:
# 2024-09-04 15:04:25,420 SequenceTagger predicts: Dictionary with 75 tags: O, S-PERSON, B-PERSON, E-PERSON, I-PERSON, S-GPE, B-GPE, E-GPE, I-GPE, S-ORG, B-ORG, E-ORG, I-ORG, S-DATE, B-DATE, E-DATE, I-DATE, S-CARDINAL, B-CARDINAL, E-CARDINAL, I-CARDINAL, S-NORP, B-NORP, E-NORP, I-NORP, S-MONEY, B-MONEY, E-MONEY, I-MONEY, S-PERCENT, B-PERCENT, E-PERCENT, I-PERCENT, S-ORDINAL, B-ORDINAL, E-ORDINAL, I-ORDINAL, S-LOC, B-LOC, E-LOC, I-LOC, S-TIME, B-TIME, E-TIME, I-TIME, S-WORK_OF_ART, B-WORK_OF_ART, E-WORK_OF_ART, I-WORK_OF_ART, S-FAC
# 100%|██████████| 2995/2995 [17:44<00:00,  2.81it/s]

# %%
message_ids = []
labels = []
label_texts = []

for row in hacktivist_messages.iterrows():
    sentence = row[1]["NER"]
    message_id = row[1]["Message Id"]
    for label in sentence.get_labels():
        message_ids.append(message_id)
        labels.append(label.value)
        label_texts.append(label.data_point.text)

ner_tagged_data = pd.DataFrame({
    "message_ids": message_ids, 
    "text": label_texts,
    "label":labels
})

# %%
message_ids = []
labels = []
label_texts = []

for row in hacktivist_messages.iterrows():
    sentence = row[1]["NER_onto"]
    message_id = row[1]["Message Id"]
    for label in sentence.get_labels():
        message_ids.append(message_id)
        labels.append(label.value)
        label_texts.append(label.data_point.text)

ner_tagged_data_onto = pd.DataFrame({
    "message_ids": message_ids, 
    "text": label_texts,
    "label":labels
})

# %%
ner_tagged_data_onto
# Out:
#        message_ids                    text   label
# 0                1                   OSINT     ORG
# 1                1             Cyberknow20  PERSON
# 2                1             pro-Russian    NORP
# 3                2                   Today    DATE
# 4                2                  Poland     GPE
# ...            ...                     ...     ...
# 14052         3003                  Russia     GPE
# 14053         3003                 Russian    NORP
# 14054         3003  DDoSia Project|Reserve     ORG
# 14055         3004                 Russian    NORP
# 14056         3004  DDoSia Project|Reserve     ORG
#
# [14057 rows x 3 columns]

# %%
ner_tagged_data_onto.label.unique()
# Out:
# array(['ORG', 'PERSON', 'NORP', 'DATE', 'GPE', 'LOC', 'TIME', 'CARDINAL',
#        'EVENT', 'LANGUAGE', 'ORDINAL', 'FAC', 'WORK_OF_ART', 'PRODUCT',
#        'QUANTITY', 'MONEY', 'PERCENT', 'LAW'], dtype=object)

# %%
sorted(ner_tagged_data_onto[(ner_tagged_data_onto["label"] == 'NORP') |
                            (ner_tagged_data_onto["label"] == 'GPE') |
                            (ner_tagged_data_onto["label"] == 'LOC')
                            ]["text"].unique())
# Out:
# ['Aarhus',
#  'Africa',
#  'Agder',
#  'Aichi Prefecture',
#  'Albania',
#  'Albanian',
#  'Albion',
#  'Aleksandrov Kuyavsky',
#  'Algeciras',
#  'Alicante',
#  'America',
#  'American',
#  'Americans',
#  'Amis',
#  'Amsterdam',
#  'Anglo-Saxon',
#  'Anglo-Saxons',
#  'Argentina',
#  'Armenia',
#  'Asia',
#  'Asturian',
#  'Asturias',
#  'Athens',
#  'Atlantic',
#  'Australia',
#  'Australian',
#  'Austria',
#  'Austrian',
#  'AzzaSec',
#  'Balearic',
#  'Baltic',
#  'Baltic Anti-Fascists',
#  'Baltic Sea',
#  'Baltics',
#  'Baltics.',
#  'Balts',
#  'Bandera',
#  'Bandera.',
#  'Bandera.We',
#  'Banderaites',
#  'Banderite',
#  'Banderites',
#  'Banskobystrický kraj',
#  'Banská Bystrica',
#  'Barcelona',
#  'Basel',
#  'Basovka',
#  'Basque',
#  'Bayreuth',
#  'Belarus',
#  'Belarusian',
#  'Belarusians',
#  'Belgian',
#  'Belgians',
#  'Belgium',
#  'Belgorod',
#  'Bellinzona',
#  'Belovody',
#  'Bergamo',
#  'Berlin',
#  'Bielefeld',
#  'Bilbao',
#  'Birmingham',
#  'Black Sea',
#  'Bogota',
#  'Bologna',
#  'Bolzano',
#  'Bordeaux',
#  'Borel',
#  'Brazil',
#  'Bremen',
#  'Brighton',
#  'Britain',
#  'British',
#  'British Columbia',
#  'British-trained',
#  'Brno',
#  'Brodnitsa',
#  'Brussels',
#  'Brussels-Charleroi',
#  'Brussels.The',
#  'Buckfastley',
#  'Budapest',
#  'Bulgaria',
#  'Bulgarian',
#  'Buox',
#  'Burgas',
#  'Bürgenstock',
#  'Cagliari',
#  'Canada',
#  'Canadian',
#  'Canadians',
#  'Cartagena',
#  'Catalan',
#  'Catalonia',
#  'Caucasian',
#  'Central and Eastern Europe',
#  'Cezanne',
#  'China',
#  'China.The',
#  'Chisinau',
#  'Christian',
#  'Cologne',
#  'Colombia',
#  'Constanta county',
#  'Copenhagen',
#  'Crimea',
#  'Crimean',
#  'Croatia',
#  'Croatian',
#  'CyberDragon',
#  'Cyprus',
#  'Czech',
#  'Czech Republic',
#  'Czech-Ukrainian',
#  'Czechia',
#  'Czechoslovak',
#  'Czechs',
#  'Dachser - German',
#  'Danes',
#  'Danish',
#  'Den Helder',
#  'Denmark',
#  'Deutschland',
#  'Dnieper',
#  'Dniester',
#  'Dnipro',
#  'Dolomites',
#  'Donbas',
#  'Donbass',
#  'Donetsk',
#  'Dortmund',
#  'Druzhba',
#  'Dutch',
#  'Earth',
#  'East',
#  'East Cambridgeshire',
#  'Eastern',
#  'Eastern Europe',
#  'Edinburgh',
#  'El Ferrol',
#  'England',
#  'English',
#  'Erfurt',
#  'Esbjerg',
#  'España',
#  'Estonia',
#  'Estonian',
#  'Estonians',
#  'Eurasia',
#  'Europe',
#  'Europe.And',
#  'Europe.Demonstrators',
#  'Europe.Recall',
#  'European',
#  'European Russophobes',
#  'Europeans',
#  'Fatherland',
#  'Finland',
#  'Finnish',
#  'Finns',
#  'Flemish',
#  'Florenc',
#  'France',
#  'France.',
#  'France.But',
#  'Frankfurt',
#  'Frattasi',
#  'Freiburg',
#  'French',
#  'FuckNATOFollow',
#  'Galicia',
#  'Gascony',
#  'Gaza',
#  'Gdansk',
#  'Gdańsk',
#  'Gdynia',
#  'Geneva',
#  'Genoa',
#  'Georgia',
#  'German',
#  'Germans',
#  'Germany',
#  'Germany.',
#  'Glogow',
#  'Golfo Aranci',
#  'Gorzow Wielkopolski',
#  'Granada',
#  'Great Britain',
#  'Greece',
#  'Greek',
#  'Greeks',
#  'Hakata',
#  'Hakodate',
#  'Halkidiki',
#  'Hanko',
#  'Hannover',
#  'Hartland',
#  'Havre',
#  'HeartLand',
#  'Helsingborg',
#  'Helsinki',
#  'Hiiumaa',
#  'Hokkaido Prefecture',
#  'Hove',
#  'Hrapovshchyna',
#  'Huelva',
#  'Hungarian',
#  'Hungary',
#  'Iceland',
#  'Icelandic',
#  'India',
#  'Indian',
#  'Ireland',
#  'Israel',
#  'Israeli',
#  'Italian',
#  'Italians',
#  'Italy',
#  'Italy.',
#  'Ivano-Frankivsk',
#  'Japan',
#  'Japan.',
#  'Japan.The',
#  'Japanese',
#  'Jerusalem',
#  'Jonava',
#  'Juhu',
#  'Kaliningrad',
#  'Kalmar',
#  'Kaunas',
#  'Kharkiv',
#  'Kharkov',
#  'Kharkov city',
#  'Khoten',
#  'Kiel',
#  'Kiev',
#  'Kiev city',
#  "Kiev.Let's",
#  'Killnet',
#  'Kingdom',
#  'Klaipeda',
#  'Kosovo',
#  'Krakow Nowa Huta',
#  'Kronvalda Park.From',
#  'Krotoshin',
#  'Krulevets',
#  'Kursk Oblast',
#  'Kursk Region',
#  'Kvertus - Ukrainian',
#  'Kyiv',
#  'Kyiv.',
#  'Kyiv.Following',
#  'Kyiv.Justin',
#  'Kyiv.Lecornu',
#  'Kyiv.Our',
#  'Lapland',
#  'Las Palmas',
#  'Latin America',
#  'Latvia',
#  'Latvian',
#  'Latvians',
#  'Lausanne',
#  'Legnica',
#  'Leicestershire County',
#  'Lengmatta',
#  'Leningrad Region',
#  'Liberec',
#  'Liechtenstein',
#  'Liepaja',
#  'Lisbon',
#  'Lithuania',
#  'Lithuanian',
#  'Lithuanians',
#  'Livonia',
#  'Ljubljana',
#  'Lobez',
#  'Lombardy',
#  'London',
#  'Lower Saxony',
#  'Lublin Voivodeship',
#  'Lucerne',
#  'Lugansk',
#  'Lugansk city',
#  'Lugo',
#  'Luhansk',
#  'Luxembourg',
#  'Luxembourgian',
#  'Lviv',
#  'Macedonian',
#  'Madrid',
#  'Malaga',
#  'Malmö',
#  'Malta',
#  'Maribor',
#  'Mazury Voivodeship',
#  'Mecca',
#  'Mecklenburg-Vorpommern',
#  'Mediterranean',
#  'Mersrag',
#  'MiG-29',
#  'Milan',
#  'Modena',
#  'Moldova',
#  'Moldovan',
#  'Montreal',
#  'Montreux',
#  'Moroccan',
#  'Morocco',
#  'Moscow',
#  'Motherland',
#  'Munich',
#  'Murcia',
#  'Málaga',
#  'Naantali',
#  'Nagoya City',
#  'Naples',
#  'Nazi',
#  'Nazis',
#  'Nazism',
#  'Netherlands',
#  'Netherlands.Today',
#  'New Occitanie',
#  'New York',
#  'New Zealand',
#  'Newcastle',
#  'Nice',
#  'Nidwalden',
#  'Niger',
#  'Nikolayevo-Daryino',
#  'NoName057',
#  'Nord Stream',
#  'Nordland',
#  'Normandy',
#  'North America',
#  'North American',
#  'North Macedonia',
#  'Northern Adriatic',
#  'Northern European',
#  'Northern Military District',
#  'Norway',
#  'Norwegian',
#  'Nowy Dwor Mazowiecki',
#  'Nuremberg',
#  'Obwalden',
#  'Occitanie',
#  'Odense',
#  'Odessa',
#  'Odessa city',
#  'Odessa.',
#  'Olbia',
#  'Oleshnya',
#  'Orthodox',
#  'Oskarshamn',
#  'Oslo',
#  'Ostrava',
#  'Oulu',
#  'Palanga',
#  'Palermo',
#  'Palestine',
#  'Palma de Mallorca',
#  'Paris',
#  'Perth',
#  'Peterhof',
#  'Phoenix',
#  'Pilsen',
#  'Piraeus',
#  'Poitiers',
#  'Poland',
#  'Poles',
#  'Polish',
#  'Polish-Ukrainian',
#  'Pori',
#  'Portugal',
#  'Portuguese',
#  'Prague',
#  'Pro-Russian',
#  'Pskov',
#  'Quebec',
#  'Ramstein',
#  'Rawa-Russka',
#  'Redzikowo',
#  'Rezekne',
#  'Rezekne Municipality',
#  'Riga',
#  'Rivne',
#  'Roman',
#  'Romania',
#  'Romanian',
#  'Rome',
#  'Ruhr',
#  'Russia',
#  'Russia.In',
#  'Russia.It',
#  'Russia.Today',
#  'Russian',
#  'Russian-Finnish',
#  'Russian-Italian',
#  'Russian-Ukrainian',
#  'Russian-speaking',
#  'Russians',
#  'Russophobe',
#  'Russophobes',
#  'Russophobia',
#  'Russophobia.Now',
#  'Russophobic',
#  'Russophobic German',
#  'Russophobic Germany',
#  'Russophobic Polish',
#  'Russophobic Western',
#  'Rzeszow',
#  'Rzeszow City',
#  'Rzeszow.Meanwhile',
#  'SS',
#  'Saaremaa',
#  'Saarland',
#  'Saguenay',
#  'San Fernando de Henares',
#  'Sardinia',
#  'Saxony-Anhalt',
#  'Scandinavian',
#  'Schaffhausen',
#  'Schleswig-Holstein',
#  'Schraemli',
#  'Scotland',
#  'Scottish',
#  'Serbia',
#  'Serbian',
#  'Sevastopol',
#  'Seville',
#  "Seville city's",
#  'Shimokita Peninsula',
#  'Siauliai',
#  'Siena',
#  'Sieradz',
#  'Skopje',
#  'Skulte',
#  'Slavic',
#  'Slovak',
#  'Slovakia',
#  'Slovakian',
#  'Slovenes',
#  'Slovenia',
#  'Slovenian',
#  'Sofia',
#  'Sofia.And',
#  'Sondrio',
#  'South Africa',
#  'South African',
#  'South Bohemian',
#  'South Korea',
#  'South Tyneside',
#  'South Yorkshire',
#  'South-Donetsk',
#  'Soviet',
#  'Spain',
#  'Spain.',
#  'Spain.Unfortunately',
#  'Spaniard',
#  'Spaniards',
#  'Spanish',
#  'Sroda-Slianska',
#  'St. Gallen',
#  'St. Moritz',
#  'St. Petersburg',
#  'Stans',
#  'Stockholm',
#  'Stuttgart',
#  'Sumy',
#  'Sunderland',
#  'Sundsvall',
#  'Sushki',
#  'Swede',
#  'Sweden',
#  'Sweden.It',
#  'Sweden.We',
#  'Swedes',
#  'Swedish',
#  'Swedish-Finnish',
#  'Swiss',
#  'Swiss-Ukrainian',
#  'Switzerland',
#  'Switzerland.And',
#  'Syria',
#  'Szczecin',
#  'Sölvesborg',
#  'Tallinn',
#  'Tampere',
#  'Tarnów',
#  'Tenerife',
#  'Ternopil',
#  'Thames',
#  'The Baltic Russophobes',
#  'The Czech Republic',
#  'The Hague',
#  'The Kingdom of Crooked Mirrors',
#  'The Province of North Brabant',
#  'The Upper Garonne',
#  'Thessaloniki',
#  'Titose',
#  'Tokyo',
#  'Toledo',
#  'Tomakomaihttps',
#  'Transnistria',
#  'Trento',
#  'Trenčín Region',
#  'Tri-City',
#  'Trieste',
#  'Trnava',
#  'Trois-Rivieres',
#  'Troms',
#  'Turin',
#  'Turku',
#  'Twitter.Joan',
#  'U.S.',
#  'UK',
#  'US',
#  'USA',
#  'USSR',
#  'Uddevalla',
#  'Ukraine',
#  'Ukraine.',
#  'Ukraine.And',
#  'Ukraine.Apparently',
#  'Ukraine.Danish',
#  'Ukraine.Earlier',
#  "Ukraine.It's",
#  'Ukraine.Well',
#  'Ukrainian',
#  'Ukrainian Nazis',
#  'Ukrainian Nazism',
#  'Ukrainian Orthodox',
#  'Ukrainians',
#  'Ukrainе',
#  'Ukroadmins',
#  'Ukronazi',
#  'Ukronazis',
#  'Ukronazism.Britain',
#  'Ukronazists',
#  'Ukroneo-Nazi',
#  'Umeå',
#  'Upper Garonne',
#  'Usti nad Labem',
#  'Vaasa',
#  'Valencia',
#  'Valencian',
#  'Varna',
#  'Velenje City',
#  'Venice',
#  'Ventspils',
#  'Vianden',
#  'Vienna',
#  'Vigo',
#  'Ville',
#  'Vilnius',
#  'Vistula',
#  'Vlaardingen',
#  'Volga',
#  'Volyn',
#  'Warmia',
#  'Warsaw',
#  'Washington',
#  'Weeze',
#  'West',
#  'West - Italian',
#  'West Götaland',
#  'West Yorkshire',
#  'West.But',
#  'Western',
#  'Western Europe',
#  'Western Russophobes',
#  'Western Ukraine',
#  'Wlodawa',
#  'Wągrowiec',
#  'Xecatsha',
#  'Yahodyn',
#  'Yawor',
#  'Yugoslav',
#  'Yugoslavia',
#  'Yukon',
#  'Yunakovka',
#  'Zakopane',
#  'Zaporizhia',
#  'Zaporizhzhya',
#  'Zaporizhzhya city',
#  'Zaporozhye',
#  'Zaragoza',
#  'Zelenskolgo',
#  'Zelensky',
#  'Zelensky.Szijjártó',
#  'Zhuravka',
#  'Zhytomyr',
#  'Zielona',
#  'Zory',
#  'Zurich',
#  'an Orthodox Christian',
#  'anti-Russian',
#  'anti-Soviet',
#  'anti-Ukrainian',
#  'economy.Lithuanian',
#  'germans',
#  'neo-Nazi',
#  'neo-Nazis',
#  'neo-Nazis-Banderites',
#  'poland',
#  'pro-Bandera',
#  'pro-European',
#  'pro-Russian',
#  'pro-Ukrainian',
#  'the Adriatic Sea',
#  'the Alpine Republic',
#  'the Balearic Islands',
#  'the Baltic Russophobes',
#  'the Baltic Sea',
#  'the Baltic States',
#  "the Basque Country's",
#  'the Black Sea',
#  'the Blekinge region',
#  'the Canary Islands',
#  'the Central-North Tyrrhenian Sea',
#  'the Chechen Republic',
#  'the City of Murcia',
#  'the Crimean Peninsula',
#  'the Czech Republic',
#  "the Czech Republic's",
#  'the Czech Republic.We',
#  'the Dutch Russophobes',
#  'the Eastern Adriatic',
#  'the Eastern European Empire',
#  'the Estonian Defense League',
#  'the Federal Republic',
#  'the Federal Republic of Germany',
#  'the Federal Republic of Germanycheck-host.net',
#  'the Federal State of Mecklenburg-Vorpommern',
#  'the Gagauz Republic',
#  'the Gulf of Riga',
#  'the Holy League',
#  'the Iberian Peninsula',
#  'the Kuyavian-Pomeranian Voivodeship of Poland',
#  'the Liberec Region of the Czech Republic',
#  'the Middle East',
#  'the Navy.The United Kingdom',
#  'the North Atlantic',
#  'the Northern Military District',
#  'the Northern Tyrrhenian Sea',
#  'the Olomouc Region of the Czech Republic',
#  'the Podkarpackie Voivodeship',
#  "the Polish People's Republic",
#  'the Pomeranian Voivodeship of Poland',
#  'the Republic',
#  'the Republic of Belarus',
#  'the Republic of Bulgaria',
#  'the Republic of Cypruscheck-host.net',
#  'the Republic of Latvia',
#  'the Republic of Lithuania',
#  'the Republic of Moldova',
#  'the Republic of Moldovacheck-host.net',
#  'the Republic of North Macedonia',
#  'the Republic of Slovenia',
#  'the Republic of Sloveniacheck-host.net',
#  'the Russian Empire',
#  'the Russian Federation',
#  'the Russian Orthodox',
#  'the Russophobic Czech Republic',
#  'the Saimaa River',
#  'the Sejm of Poland',
#  'the Slovak Republic',
#  'the Soviet Union',
#  'the Swietokrzyski Voivodeship of Poland',
#  'the Trnavka River',
#  'the Ukrainian Nazis',
#  'the United Kingdom',
#  'the United States',
#  'the United States of America',
#  'the United States.',
#  'the Vistula Spit River',
#  'the World Island',
#  'ukrainian',
#  'Šiauliai']

# %%
sorted(ner_tagged_data_onto[(ner_tagged_data_onto["label"] == 'ORG')]["text"].unique())
# Out:
# ['"A1 Telekom Austria Group"',
#  '"Banca Monte dei Paschi di Siena"',
#  '"Banca Popolare di Bari"',
#  '"Banca Popolare di Sondrio"',
#  '"CARS OLIVIER"',
#  '"Catalonia Hotels & Resorts"',
#  '"Clearing House"',
#  '"Creand Wealth Management"',
#  '"Credit Agricole Bank"',
#  '"Delfi Estonia"',
#  '"East Japan Railway Co"',
#  '"Expansión"🔥Resource',
#  '"Grifs" LLC',
#  '"Ignitis gamyba"',
#  '"Industrial Bank"',
#  '"Lithuanian Airports"',
#  '"Lvovoblenergo"',
#  '"Majestic Hotel Group"',
#  '"PCC-Cert"',
#  '"PKP Polskie Linie Kolejowe S.A."',
#  '"Special Innovative Technologies"',
#  '"System Capital Management',
#  '"Ukrhydroenergo"',
#  '"Velta"',
#  '"Zhytomyr Regional Energy Supply Company"',
#  '11fd9d4dk4ac❎Italian National Association of Financial Planners',
#  '143972a8ka5a❌Financial Group',
#  '14f8071ck51a❌ Bank of Finland',
#  '1522c082k56Helsinki Region Transport',
#  '176ab60cke6f  ❌Committee on Energy and Housing and Communal Services',
#  '199b916dkac❌Committee on Energy and Housing and Communal Services',
#  '19cc90b6k4bf❌Moldovan Ministry of Foreign Affairs',
#  '19ebedefkaea❌Helsinki Region Chamber of Commerce',
#  '1a48cf12ka3f❌Aernnova Aerospace Corporation',
#  '1b39d3f7k2ae❌Committee on Energy and Housing and Communal Services',
#  '1b5a1238k22c❌Committee on Energy and Housing and Communal Services',
#  '1c7472fck7ee❌ Murcia City Council Housing Service',
#  '1cbb881akfaf❌Spain Constitutional Court',
#  '1cda17fak13e❌ Murcia City Council Housing Service',
#  '1d1b8ec2kadf❌Committee on Energy and Housing and Communal Services',
#  '1d3f59ebk3ca❌Law Enforcement Committee',
#  '22C',
#  '25th Air Defense Missile Regiment',
#  '313 Team',
#  '3rd Assault Brigade',
#  '7 October Union',
#  'A.O',
#  'A2A S.p.A.',
#  'ABANCA',
#  'ABANCA Corporación Bancaria',
#  'ACS',
#  'ADAC',
#  'AFU',
#  'AGCM',
#  'ALFE BRNO',
#  'AMAT',
#  'AMAT Palermo',
#  'AMX-10 RC',
#  'ANASF',
#  'APC',
#  'APU',
#  'ARPA',
#  'ART)',
#  'AS Tallinna Sadam',
#  'ASBE',
#  'ASSOSIM',
#  'ATAP',
#  'ATAP - Turin',
#  "ATAP - Turin's",
#  'AVL',
#  'AXA Bank',
#  'AXA Group',
#  'AamiGO',
#  'Aareal Bank',
#  'Accordbank',
#  'Achema',
#  'Adelaide Bank',
#  'Adif',
#  'Adrem',
#  'Aedificium Banca',
#  'Agency',
#  'Agency for the Regulation and Development of Transportation and Communication Infrastructure',
#  'Air Bank',
#  'Air Force',
#  'AirDolomiti',
#  'Airdolimiti',
#  'Akhmetov R.L.',
#  'Akropolis',
#  'Aktia',
#  'Aktia Bank Plc',
#  'Al Ahad',
#  'Albanian Parliament',
#  'Albanian Railways',
#  'Albastar',
#  'Alfa',
#  'Alior Bank',
#  'AlixSec',
#  "All Rus'",
#  'Alliance',
#  'Allied Special Operations Forces Command',
#  'Alony Hetz',
#  "Alony Hetz Israel's",
#  'Alpenhof Davos',
#  'Alpha Bank',
#  'Alpha Bank Cyprus',
#  'Alpha Bank Romania',
#  'Alpha Bank Romania S.A',
#  'Alpi Aviation',
#  'Altero',
#  'Amat Palermo',
#  'American Patriot',
#  'Ani',
#  'Anonymous Arabs',
#  'Anonymous DZ',
#  'Anonymous Guys',
#  'Aomori Airport',
#  'Aomori Airportcheck-host.net',
#  'Aomori Railway Company',
#  'Aquatic Affairs',
#  'Arkema',
#  'Armed Forces',
#  'Army',
#  "Army.Let's",
#  'Arriva - Transport',
#  'Arriva Group',
#  'Asociación Española de la Carretera',
#  'Assembly',
#  'Association of Banks',
#  'Association of Engineers',
#  'AstroNetworks',
#  'Atac SpA',
#  'Atagor',
#  'Atende',
#  'Atlanta Data Center',
#  'Aude',
#  'Aurida Logistics Solutions',
#  'Australian Department of Home Affairs',
#  'Austrian Press Agency',
#  'Autodafe',
#  'Autostrada Eksploatacja',
#  'Avanza',
#  'Avanza Bank',
#  'Avanza Bus',
#  'Avast',
#  'Avia',
#  'Avio S.p.A.',
#  'Avion Express',
#  'Azienda Consorzio Trasporti Veneziano',
#  'Azienda Napoletana Mobilità',
#  'Azienda Regionale Sarda Trasporti"',
#  'Azienda Trasporti Bergamo',
#  'AzzaSec',
#  'B&D Services',
#  'BAE Systems',
#  'BANCA MPS',
#  'BAP',
#  'BCE Inc.',
#  'BCR Chişinău S.A.',
#  'BDB',
#  'BEAR.IT.ARMY',
#  'BEARSPAWWe',
#  'BFMTV',
#  'BKT',
#  'BLRT',
#  'BLRT Grupp',
#  'BMPS',
#  'BNP Paribas Bank Polska',
#  'BNS',
#  'BOŚ Bank',
#  'BPER',
#  'BPER Banca',
#  'BPER CBI',
#  'BRICS',
#  'BVG',
#  'BaFin',
#  'Bae Systems',
#  'Baltic Air Logistics Terminal',
#  'Baltic Marine Spedition',
#  'Baltic News Service',
#  'Baltic news agency',
#  'Balticum',
#  'Banca',
#  'Banca Comercială Română',
#  'Banca Comercială Română - Romanian',
#  'Banca Comercială Română Chişinău S.A',
#  'Banca Monte dei Paschi di Siena',
#  'Banca Popolare di Bari',
#  'Banca Popolare di Sondrio Italian',
#  'Banca Popolare di Sondrio Spa',
#  'Banco Cooperativo Español',
#  'Banco Mediolanum',
#  'Banco Sabadell',
#  'Bandera',
#  'Bandera.This',
#  'Bandera’s',
#  'Bank Discount',
#  'Bank Millennium',
#  'Bank Polska Kasa',
#  'Bank Polska Kasa Opieki Spółka Akcyjna',
#  'Bank of Finland',
#  'Bankinter',
#  'Banks of Ukraine',
#  'Basque Parliament',
#  'Bayerische Landesbank',
#  'Bayern LB',
#  'BayernLB',
#  'Beaver',
#  'Belgian House of Representatives',
#  'Belgian Senate',
#  'Belgium.About',
#  'Bell Canada Enterprises',
#  'Beregini',
#  'Bergé Logistics',
#  'Berkut',
#  'Berliner Transport Enterprises',
#  'Berliner Verkehrsbetriebe',
#  'Black Hornet',
#  'Black Wolfs',
#  'Bollington City Council',
#  'Boreal Norge',
#  'Bratstvo',
#  'Breitto',
#  'British Helicopter Association',
#  'British Industry',
#  'Brno International',
#  'Brno-Tuřany Airport',
#  'Bulgarian Chamber of Commerce',
#  'Bulgarian National Bank',
#  'Bundestag',
#  'Bundeswehr',
#  'Bundeswehr Information Technology School for the German Armed Forces',
#  'Burbock',
#  'Bus Éireann',
#  'Bürgenstock',
#  'CAESAR',
#  'CCAS',
#  'CCN',
#  'CERT',
#  'CFR Marfă',
#  'CIMSA',
#  'CIRC',
#  'CIS',
#  'CMRE',
#  'CNH Industrial',
#  'CNI',
#  'COE',
#  'CONSOB',
#  'CONSOB) - Italian Securities and Exchange Commission',
#  'CORPEX',
#  'CRIF',
#  'CSA',
#  'CSA Czech Airlines',
#  'CSIRT GOV',
#  'CTM',
#  'CV-90',
#  'CZSO',
#  'Cabinet',
#  'Cadiz Bay Port Authority',
#  'Cagliari Trasporti Mobilità',
#  'Cambridgeshire East',
#  'Canada Border Services Agency',
#  'Canadian Aviation Safety Agency',
#  'Canadian Bankers Association',
#  'Canadian Chamber of Commerce',
#  'Canadian Metropolitan Transportation Association',
#  'Canadian Pacific Railway Limited',
#  'Canadian Transportation Agency',
#  'Canal de Isabel II',
#  'Canary Islands Parliament',
#  'Carabinieri',
#  'Cargo',
#  'CargoGO',
#  'Cargobooking',
#  'Cargogo',
#  'Carta Nazionale dei Servizi',
#  'Catalan Parliament',
#  'Catalonia Parliament',
#  'Cde Cantos',
#  'Central Bank',
#  'Central Bank of Finland',
#  'Central Chamber of Commerce',
#  'Central Chamber of Commerce and Industry',
#  'Central Chamber of Commerce and Industry of Finland',
#  'Central Chamber of Commerce of Finland',
#  'Central Interregional Department',
#  'Central Japan Railway Co',
#  'Cert',
#  'Chamber of Commerce',
#  'Chamber of Commerce and Industry',
#  'Chamber of Commerce and Industry of Finland',
#  'Chamber of Commerce and Industry of Slovenia',
#  'Chamber of Commerce of Finland',
#  'CheBanca',
#  'Chronicle',
#  'Citadele',
#  'City Service',
#  'Civil Aviation Administration',
#  'Civil Aviation Authority',
#  'ColtisHere',
#  'Comando de Fuerzas Aliadas de Operaciones Especiales de la OTAN',
#  'Committee on Energy and Housing and Communal Services',
#  'Committee on Energy and Public Utilities',
#  'Committee on Homeland Security',
#  'Committee on State Power',
#  'Committee on Transportation and Infrastructure',
#  'Confederation of British Industry',
#  'Conrad Shipyard',
#  'Constitutional Court',
#  'Coop',
#  'Cooppank',
#  'Copenhagen Airport',
#  'Correos',
#  'Corriere della Sera',
#  'Corsica Ferries',
#  'Council of Europe',
#  'Council of Ministers of Spain',
#  'Council of National Security and Defense',
#  'Coup Team',
#  'Cranbrook City Council',
#  'Cranbrook Town Council',
#  'Creand Wealth Management',
#  'Credem Banca',
#  'Credit Agricole',
#  'Credit Agricole Bank',
#  'Credit Agricole Bank Polska',
#  'Credit Agricole Bank"',
#  'Credit Europe Bank',
#  'Credit Europe Bank Banking Group',
#  'Credit Union',
#  'Credito Cooperativo',
#  'Credito Emiliano',
#  'Crimean Platform',
#  'Croatian Ministry of Finance',
#  "Croatian People's Bank",
#  'Croatian Tax Administration',
#  'Cropp',
#  'Crosetto',
#  'Crowdestate',
#  'Cryptaris',
#  'CryptoCorp',
#  'Customs',
#  'Cyber Army',
#  'Cyber Dragon.Follow',
#  'Cyber Security',
#  'Cyber Security Command',
#  'Cyber Security Service',
#  'CyberArmy',
#  'CyberArmy HackNeT22C',
#  'CyberArmy Of Russia',
#  'CyberDragon',
#  'CyberDragon и NETWORK',
#  'CyberHood',
#  'CyberKnow',
#  'CyberStine',
#  'CyberVolk',
#  'Cybersecurity Operations Center',
#  'Czech Association of Financial',
#  'Czech Export Guarantee and Insurance Corporation',
#  'Czech Export Promotion Agency',
#  'Czech Insurance Agency',
#  'Czech Ministry of Transport',
#  'Czech National Bank',
#  'Czech Republic Army',
#  'Czech Republic Police',
#  'Czech Road and Motorway Administration',
#  'Cámara de Comercio Regional de Odesa',
#  'DAT',
#  'DB Cargo',
#  'DBP',
#  'DDoS-cargo',
#  'DDoS-hail',
#  'DDoS-hello',
#  'DDoSia',
#  'DDoSia Project',
#  'DDoSia Project.',
#  'DDoSia Project|Reserve',
#  'DDoSia/NoName057',
#  'DDosia Project',
#  'DE SISTEMAS S.A',
#  'DE SISTEMAS S.A.',
#  'DEADFOUD',
#  'DIANA',
#  'DOC',
#  'DOD Image Bank ❌ Chamber of Commerce and Industry',
#  'DOT',
#  'DOT LT',
#  'DSK',
#  'DSK Bank',
#  'DXQRTXX',
#  'DaZBasta',
#  'DaZbastaDraw',
#  'Danish Ministry of Defense',
#  'Danish Ministry of Finance',
#  'Danish Ministry of Taxes',
#  'Danish National Bank',
#  'Danish Road Safety Council',
#  'Danish Tax Agency',
#  'Danish Transport Authority',
#  'Danske',
#  'Danske Rederier',
#  'Danskebank',
#  'DataSafe',
#  'Datalogistics',
#  'Davos',
#  'Davos-Klosters',
#  'DazBasta',
#  'De Craw',
#  'De Cro',
#  'De Lijn',
#  'De-Occupation and Reintegration of Temporarily Occupied Territories',
#  'Defense',
#  "Defense Forces'",
#  'Defense and Intelligence',
#  'Delegation for Road Safety',
#  'Delek Group',
#  'Delfi',
#  'Democratic Party',
#  'Democratic Unionist Party',
#  'Denmark🇩🇰❌Organization',
#  'Department of Defense',
#  'DevOps',
#  'Dezamet',
#  'Diehl Stiftung GmbH & Co',
#  'Diehl Stiftung GmbH & Co. KG',
#  'Digital Infrastructure',
#  'Digital Infrastructure of Germany',
#  'Digital Office',
#  'Digital Revolt',
#  "Digital Sovereignty's",
#  'Digital Transformation',
#  'Digital Transformation Committee',
#  'Discount Bank',
#  "DoSSia Project's",
#  'Dosia Project',
#  'Dotpay',
#  'Doubleface',
#  'Durres Port Authority',
#  'E-P Rail. E-P Rail',
#  'E-Svitlo',
#  'E-svitlo',
#  'ECAA',
#  'EDF',
#  'EEsti Energia',
#  'ELECTRIC',
#  'ELESTER-PKP',
#  'EMT',
#  'EMT Málaga',
#  'EP',
#  'ERR',
#  'ERR.EE',
#  'ESPO',
#  'EU',
#  'EU.',
#  'EU.In',
#  'EU.Today',
#  'EU.We',
#  'EVN AG',
#  'EVR',
#  'EXCALIBUR ARMY',
#  'EXCALIBUR Army',
#  'East Cambridgeshire County Council',
#  'East Cambridgeshire District Council',
#  'East Japan Railway Co',
#  'Eesti Energia',
#  'Eesti Raudtee',
#  'Eestipank Bank',
#  'EfTEN Capital',
#  'EfTEN Real Estate Fund III AS',
#  'El Aeropuerto Internacional',
#  'El Ferrol',
#  'Electronic Money Institutions',
#  'Elmech',
#  'Eltrona Company',
#  'EnBW',
#  'Enagás',
#  'Enera Vinnitsa',
#  'Enera Vostok company',
#  'Enercoop',
#  'Energie AG',
#  'Energie Baden-Württemberg',
#  'Energie Steiermark AG',
#  'Engel Modellbau & Technik',
#  'England - NoName057',
#  'English Railways',
#  'Envelo',
#  'Eso',
#  'Esterik City Hall',
#  'Estonian Chamber of Commerce',
#  'Estonian Foreign Ministry',
#  'Estonian Transport Authority',
#  'EuRoPol GAZ',
#  'Euroclear',
#  'Eurolines',
#  'Euromaidan',
#  'Euronews',
#  'Europe.Czech',
#  'European Bank for Reconstruction and Development',
#  'European Blockchain Services',
#  "European Business Aviation Association - Europe's",
#  'European Court of Auditors',
#  'European Economic and Social Committee',
#  'European Parliament',
#  'European Political Community',
#  'European Pravda',
#  'European Sea Ports Organization',
#  'European Transfers',
#  'Euskaltel',
#  'Evention',
#  'Evercom',
#  'Everest Broadcasting Company',
#  'Everest Broadcasting Company.',
#  'Excalibur Army',
#  'Expansión',
#  'ExpressTrip',
#  'F-16',
#  'F-16s',
#  'FREUGHT',
#  'FSC',
#  'FUIB',
#  'FUIB Bank',
#  'Facebook',
#  'Farmer-Civil Movement',
#  'Febelfin',
#  'Federal Central Tax Office',
#  'Federal Constitutional Court',
#  'Federal Financial Services Supervisory Agency',
#  'Federal Legion',
#  'Federal Ministry of Justice',
#  'Federal Ministry of Justicecheck-host.net',
#  'Federal Ministry of Transport',
#  'Federal Ministry of the Interior',
#  'Federal Office for Logistics',
#  'Federal Office for the Protection of the German Constitutioncheck-host.net',
#  'Federal Office of Logistics',
#  'Federal Supreme Court of Germany',
#  'Fermat CZ',
#  'Ferrocarrils de la Generalitat de Catalunya',
#  'Fideuram',
#  'Financial Inspectorate',
#  'Financial Stability Committee',
#  'Financial Supervision Authority',
#  'Financial Supervisory',
#  'FinecoBank',
#  'Fingenia',
#  'Fingrid',
#  'Finland Central Bank',
#  'Finnish Central Bank',
#  'Finnish Chamber of Commerce and Industry',
#  'Finnish Court of Arbitration',
#  'Finnish Energy Companies',
#  'Finnish Energy Sector Companies',
#  'Finnish Road Administration',
#  'Finnish Transport and Communications Agency',
#  'Finnmark BPS Nord',
#  'Finnpilot Pilotage Oy',
#  'First Officially Established Insurance Company',
#  'Fjord Line',
#  'Folk',
#  'Forbes',
#  'Foreign Affairs',
#  'Foreign Ministry',
#  'Fortinet',
#  'Fraternité - the NoName057',
#  'Free Press Unlimited',
#  'Freezl',
#  'French General Directorate of Public Finance',
#  'French Ministry of Economy',
#  'Freught',
#  'Friedrich Ebert Foundation.The foundation',
#  'Fundusz Rozwoju S.A',
#  'Fundusz Rozwoju S.A.',
#  'G20',
#  'G7',
#  'GAZ-SYSTEM',
#  'GEO',
#  'GOV',
#  'GROM',
#  'GVB',
#  'Galicia Parliament',
#  'Gascontrol Polska',
#  'Gassco',
#  'Gatwick Express',
#  'Gdańsk Transport Company',
#  'General Commissariat for Market and Competition',
#  'General Commissionerate for the Market and Competition',
#  'General Dynamics European Land Systems',
#  'General Staff',
#  'Generali',
#  'Geneva Financial',
#  'German Automobile Club ADAC',
#  'German Customs',
#  'German Customs Administration',
#  'German Federal Criminal Police Office',
#  'German Federal Ministry of Transport',
#  'German Leopard',
#  'German Ministry of Foreign Affairs',
#  'Gestapo',
#  'GetJet Airlines',
#  'Girteka',
#  'Go Vilnius',
#  'Government',
#  'Granada',
#  'Gravisnet',
#  'Great CyberVolk',
#  'Great Motherland',
#  'Greek Railroad Service',
#  'Grenchen airportcheck-host.net',
#  'Grimaldi Lines',
#  'Gripen',
#  'Groningen Delfzijl',
#  'Groupware',
#  'Grup Feroviar Roman',
#  'Grupo Caja Rural',
#  'Grupo Caja Rural Spanish Association',
#  'Grupo Oesia',
#  'Gruppo Mediolanum',
#  'Guardian.For',
#  'HCL Notes',
#  'HORIBA MIRA',
#  'HSH',
#  'HSL',
#  'HackNeT',
#  'Hackathon',
#  'Hacker Council',
#  'Hacker Council Global',
#  'Hackers',
#  'Halifax Port Authority',
#  'Hamburger Sparkasse',
#  'Hamilton-Oshawa Port Authority',
#  'Handelsbanken',
#  'Hansen Gruppen A',
#  'Hansen Gruppen A/S',
#  'Haspa',
#  'Heartland',
#  'Heathrow Express',
#  'Hebu Handels GmbH',
#  'Helaba',
#  'Helen Ltd',
#  'Heliswiss AG',
#  'Hellenic Bank',
#  'Hellenic Banking Association',
#  'Helsinki Region Transport',
#  'Helsinki Regional Chamber of Commerce and Industry',
#  'Hero of Russia',
#  'Hessen-Thüringen',
#  'Heston Airlines',
#  'HexaLocker',
#  'Hexagon',
#  'Highways of Poland',
#  'Holy League',
#  'Honshu Islandhttps',
#  'Horus Team',
#  'HorusTeam',
#  'Hot Mobile',
#  'House',
#  'House of Representatives',
#  'Hradec Králové',
#  'Hunt3rKill3rs',
#  'Husky Energy Inc',
#  'Hydro-Québec',
#  'IAMKILLMILKCyberdragonCoupTeamRoot',
#  'IBM Notes / Domino',
#  'IBM Security',
#  'ICC',
#  'IMDEA Energy',
#  'IMY',
#  'INCIBE',
#  'INGSTAD & CO',
#  'IOC',
#  'IPay',
#  'ISP',
#  'ITS',
#  'Ibercaja Banco Bank',
#  'Icelandic Parliament',
#  'Iliad Italia SpA',
#  'Industrial Bank',
#  'Industrial Safety Supervision Department',
#  'Ineco',
#  'InfoEngine SA',
#  'Information Documents Portal for Packaged Retail and Insurance Investment Products',
#  'Information Technologies',
#  'Information Technology',
#  'Inges Kindlustus',
#  'InsanePakistan',
#  'Intelligence',
#  'Intelligence Committee',
#  'Intelligent Transport Systems',
#  'Interfax-Ukraine',
#  'Internal Security Agency.We',
#  'International Development',
#  'Internews-Ukraine',
#  'Intesa Sanpaolo',
#  'Investissement Québec',
#  'Irish Ferries',
#  'Iron Wolf',
#  'Isavia',
#  'Isdefe',
#  'Isracard',
#  'Italian Air Force',
#  'Italian Association of Financial',
#  'Italian Association of Financial Intermediaries',
#  'Italian Banca Popolare di Bari',
#  'Italian Customs Telematics Service',
#  'Italian Securities Brokerage Association',
#  'Italian Securities and Exchange Commission',
#  'JEPIC',
#  'JFROG',
#  'JR East Group',
#  'JSC',
#  'JSC "Baltic Marine Spedition"',
#  'JSC "Baltic Shipping"',
#  'JSC "Eesti Energia',
#  'JSC "Kiev Plant" Radar',
#  'JSC "Kiev Radar Plant"',
#  'JSC "Universal Bank',
#  'Japan Commercial Arbitration Association',
#  'Japan Railway Co',
#  'Jazztel',
#  'Jerez de la Frontera',
#  'Jernhusen AB',
#  'Jerusalem High-Speed Tram',
#  'Julius Bär',
#  'Justin',
#  'Justin Bieber',
#  'Jyskebank',
#  'KFW',
#  'KFW Bankgruppe',
#  'KILLEDThe Spanish National Cybersecurity Institute',
#  'KLASCO',
#  'KNTEU',
#  'KTG',
#  'Kalashnikov',
#  'KaliHunt/Russia',
#  'Kammarkollegiet',
#  'Kartrans',
#  'Kauno',
#  'Kauno energija',
#  'Kelprojektas',
#  'Keltas',
#  'Keymous',
#  'Kharkiv Chamber of Commerce',
#  'Kherson City Military Council',
#  'Klaipedos Nafta',
#  'Klaipėda Sea Cargo Company AB',
#  'Kodumaa Kapital HLÜ',
#  'Koleo',
#  'Komatsu',
#  'Konan Bus',
#  'Kongsberg',
#  'Kongsberg Maritime',
#  'Konstrukta-Defence',
#  'KotoBot',
#  'Kredito',
#  'KredoBank',
#  'Kredobank',
#  'Kyivstar',
#  'KyotoSH',
#  'LC MTB Bank',
#  'LDZ',
#  'LDZ Cargo',
#  'LDZ Cargo"',
#  'LEI',
#  'LGA',
#  'LGBT',
#  'LHV Pank"',
#  'LPP',
#  'LTOU)',
#  'La Coruña',
#  'La Coruñacheck-host.net',
#  'Lagardère',
#  'Lake Lucerne - Schifffahrtsgesellschaft des Vierwaldstätterssee',
#  'Landesbank Baden-Württemberg',
#  'Landesbank Hessen-Thüringen',
#  'Lapasus',
#  'Latvenergo',
#  'Latvia Asbe',
#  'Latvia Post',
#  'LatviaGrandfather',
#  'Latvian Association of Enterprises',
#  'Latvian Chamber of Commerce',
#  'Latvian Post',
#  'Latvian Railways',
#  'Latvian Seimas',
#  'Latvian Travel Agents',
#  'Latvijas',
#  'Latviyskaya Gazeta',
#  'Laurentian Bank',
#  'Law Enforcement Committee',
#  'Law and Justice',
#  'Left Alliance',
#  'Leicestershire County Council',
#  'Leistritz AG',
#  'Leopard',
#  'Leoš Janáček',
#  'Liberal Democratic Party of Japan',
#  'Liberté',
#  'Licatrans UAB',
#  'Lietuvos',
#  'Linas Agro',
#  'Linava',
#  'Litexpo',
#  'Litgrid AB',
#  'Lithuania Vilniaus',
#  'Lithuanian Airports',
#  'Lithuanian Cargo',
#  'Lithuanian Energy Institute',
#  'Liverpool City Council',
#  'Ljubljanski potniški promet',
#  'Lk Bayerische Landesbank',
#  'Local Government',
#  'Local Self-Government',
#  'London Biggin Hill Airport',
#  'Lotus Notes',
#  'Lubusz',
#  'Lugansk Regional State Administration',
#  'LulzSec',
#  'Lulzsec Muslims',
#  'Luminor',
#  'Luxembourg Bus Company',
#  'Luxmeburg',
#  'Lvivoblenergo',
#  'Lvivska Khvilya',
#  'Lvovoblenergo',
#  'M109L',
#  'MBDA Deutschland GmbH',
#  'MBDA Deutschland GmbH"',
#  'MEO Portugal',
#  'MLRS',
#  'MLT Group',
#  'MOL Romania',
#  'MOTOR JIKOV Strojírenská',
#  'MSIAC',
#  'MTB BANK',
#  'MTB BANK JSC',
#  'MTB Bank',
#  'MTB Bank"',
#  'MTL GROUP',
#  'Maanteeamet',
#  'Macron',
#  'Madrid Metro',
#  'Malmö City Hall',
#  'Marder',
#  'Marine Projects',
#  'Martlet (=English',
#  'Matrox',
#  'Max Bank',
#  'Medbank Internet Bank',
#  'Medicinos',
#  'Mediobanca',
#  'Mediobanca Banca di Credito Finanziario SpA',
#  'Mediterranean Minoan Lines',
#  'Mercantile Discount Bank',
#  'Meris / Mēris',
#  'Merlin Scott',
#  'Mersey Ferries',
#  'MetInvest',
#  'Metinvest',
#  'Metro de Madrid',
#  'MiG',
#  'MiG-29',
#  'Milano Finanza MF',
#  'Military Review',
#  'Millog',
#  'Mincovňa Kremnica',
#  'Ministerio de Ciencia',
#  'Ministry of Agrarian Policy and Food of Ukraine',
#  'Ministry of Agriculture',
#  'Ministry of Defence',
#  'Ministry of Defense',
#  'Ministry of Defense of North Macedonia',
#  'Ministry of Defense of Slovakia',
#  'Ministry of Defense of Slovenia',
#  'Ministry of Defense of Ukraine',
#  'Ministry of Defense of the Slovak Republic',
#  'Ministry of Defense.',
#  'Ministry of Development',
#  'Ministry of Economic Development',
#  'Ministry of Economic Development and Digitalization of Moldova',
#  'Ministry of Economy',
#  'Ministry of Economy and Finance',
#  'Ministry of Energy',
#  'Ministry of Finance',
#  'Ministry of Finance of Estonia',
#  'Ministry of Foreign Affairs',
#  'Ministry of Foreign Affairs  Republic of Moldova',
#  'Ministry of Foreign Affairs Republic of Moldova',
#  'Ministry of Foreign Affairs of Moldova',
#  'Ministry of Funds',
#  'Ministry of Infrastructure',
#  'Ministry of Infrastructure and Transport',
#  'Ministry of Infrastructure and Transport of Greece',
#  'Ministry of Infrastructure and Transportation',
#  'Ministry of Internal Affairs',
#  'Ministry of Justice',
#  'Ministry of Justice of Moldova',
#  'Ministry of Justice of Romania',
#  'Ministry of Labor',
#  'Ministry of National Defense',
#  'Ministry of Transport',
#  'Ministry of Transportation',
#  'Ministry of Transportation of the Czech Republiccheck-host.net/check-report/1656cee5k45a❌Department',
#  'Ministry of the Interior',
#  'Mint',
#  'MitID',
#  "MitID portal - Denmark's",
#  'Mizuho Financial Group',
#  'Mohito',
#  'Moldova e-Government Portal',
#  'Moldovan Ministry',
#  'Moldovan Ministry of Foreign Affairs',
#  'Moldovan Public Services',
#  'Moldovan Public Services Portal',
#  'Money Advice Service',
#  'Montreal Trudeau International Airport',
#  'Moodnekodu',
#  'Moroccan Dragons',
#  'Moroccan Soldiers',
#  'Moscow closer.NoName057',
#  'Movia',
#  "Movia - Denmark's",
#  'Movistar',
#  'Mursia Regional Parliament',
#  'My House.Personal Cabinet',
#  'Myśl Polska.The',
#  'NAMCO BANDAI Holdings, Inc.',
#  'NASAMS',
#  'NATO',
#  'NATO Center for Maritime Research and Experimentation',
#  'NATO Centers of Excellence',
#  'NATO Munitions Safety Information and Analysis Center',
#  'NATO.Finland',
#  'NATOThe High Society',
#  'NBP',
#  'NEC',
#  'NEC CCIS Support Center',
#  'NED',
#  'NEOBUS POLSKA Czurczak Spółka Komandytowa',
#  'NIGHTMARE',
#  'NKON',
#  'NLETI',
#  'NPO Ukrhydroenergobud"',
#  'NVO',
#  'NWO',
#  'Nanaimo Port Administration',
#  'Nasa1788',
#  'National Academy of Sciences',
#  'National Agency for Network and Electronic Services National Council',
#  'National Assembly',
#  'National Association',
#  'National Association of Road Carriers',
#  'National Audit Commission',
#  'National Bank',
#  'National Bank of Moldova',
#  'National Bank of Romania',
#  'National Capital Commission',
#  'National Center for Cyber Security',
#  'National Center for the Unskilled',
#  'National Commission for Securities',
#  'National Communications Authority',
#  'National Council of the Republic of Sloveniacheck-host.net',
#  'National Cyber Security Agency',
#  'National Cyber Security Center',
#  'National Cyber Security Centre',
#  'National Cyber Security Institute',
#  'National Endowment for Democracy) Foundation',
#  'National Estonian',
#  'National Express',
#  "National Express - Germany's",
#  'National Minorities and Interethnic Relations',
#  'National Radio Company of Ukraine',
#  'National Securities and Stock Market Commission',
#  'National Security',
#  'National Security and Defense Council',
#  'National trade association',
#  'Naval Group',
#  'Navantia',
#  'Navy',
#  'Nederlandse Gemeenten',
#  'NetForceZ',
#  'Netherlands Public Transport Authority',
#  'New Flyer Industries Inc.',
#  'Newcastle Under Lyme Borough Council',
#  'Newsweek',
#  'Nidwalden Road Safety Center',
#  'Nidwalden.Unfortunately',
#  'Niedersachsen Ports',
#  'Nkom',
#  'NoName',
#  'NoName057',
#  'NoName05716',
#  'Nord Stream-2',
#  'NordWestBahn GmbH',
#  'Nordica',
#  'Norge',
#  'Norrtåg',
#  'Northern European Command and Control Information System',
#  'Norwegian Shipbuilding Trade Association Norwegian Shipyards',
#  'Norwegian Shipyards',
#  'Nova Bus Inc',
#  'Nova Bus Inc.',
#  ...]

# %%
ner_tagged_data_onto.to_parquet("data/ner_tagged_data_onto.parquet")
